# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
import json
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
url  = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city = "Kampala"

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
import json

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = (((pd.DataFrame(city_weather["weather"]).set_index("main")).iloc[0,1]))
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | yumen
# Processing Record 3 of Set 1 | winnemucca
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | sangar
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | cayenne
# Processing Record 9 of Set 1 | itoman
# Processing Record 10 of Set 1 | kindu
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | acapulco
# Processing Record 13 of Set 1 | balabac
# Processing Record 14 of Set 1 | carndonagh
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | saskylakh
# Processing Record 17 of Set 1 | bilibino
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | dingle
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | ndele
# Processing Record 26 of Set 1 | cozumel
# Processing Record 27 of Set 1 | altamira
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | havoysund
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | ambovombe
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | tuatapere
# Processing Record 36 of Set 1 | killybegs
# Processing Record 37 of Set 1 | tagusao
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | leningradskiy
# Processing Record 41 of Set 1 | adrar
# Processing Record 42 of Set 1 | chingirlau
# Processing Record 43 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | mataram
# Processing Record 46 of Set 1 | puerto quijarro
# Processing Record 47 of Set 1 | kihei
# Processing Record 48 of Set 1 | port blair
# Processing Record 49 of Set 1 | lorengau
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | nizhnyaya tura
# Processing Record 2 of Set 2 | muttenz
# Processing Record 3 of Set 2 | jalu
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | nyurba
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | amapa
# Processing Record 14 of Set 2 | nykoping
# Processing Record 15 of Set 2 | labuan
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | boddam
# Processing Record 18 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 2 | grindavik
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 2 | garden city
# Processing Record 24 of Set 2 | tuntum
# Processing Record 25 of Set 2 | chanute
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | troitsko-pechorsk
# Processing Record 28 of Set 2 | denpasar
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | sao filipe
# Processing Record 32 of Set 2 | katobu
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | port keats
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | zilupe
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | ilulissat
# Processing Record 47 of Set 2 | madras
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | katsuura
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | nanortalik
# Processing Record 2 of Set 3 | mareeba
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | jadu
# Processing Record 5 of Set 3 | makakilo city
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | nauta
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | dingli
# Processing Record 10 of Set 3 | eureka
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | udachnyy
# Processing Record 13 of Set 3 | margate
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | gayny
# Processing Record 16 of Set 3 | fairbanks
# Processing Record 17 of Set 3 | homer
# Processing Record 18 of Set 3 | kavieng
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | clyde river
# Processing Record 23 of Set 3 | srednekolymsk
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | griffith
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | colac
# Processing Record 29 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 3 | kharp
# Processing Record 31 of Set 3 | charters towers
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | myre
# Processing Record 35 of Set 3 | hermanus
# Processing Record 36 of Set 3 | tiznit
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | bereda
# Processing Record 39 of Set 3 | bhera
# Processing Record 40 of Set 3 | hima
# Processing Record 41 of Set 3 | eyl
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | dunajska streda
# Processing Record 44 of Set 3 | goderich
# Processing Record 45 of Set 3 | edgewater
# Processing Record 46 of Set 3 | vaini
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | tres arroyos
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | edd
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | poum
# Processing Record 5 of Set 4 | ostrovnoy
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | cockburn town
# Processing Record 8 of Set 4 | marzuq
# Processing Record 9 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 4 | sao lourenco do oeste
# Processing Record 11 of Set 4 | sheridan
# Processing Record 12 of Set 4 | klaksvik
# Processing Record 13 of Set 4 | flin flon
# Processing Record 14 of Set 4 | kuybyshevo
# Processing Record 15 of Set 4 | campbell river
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | tual
# Processing Record 18 of Set 4 | atar
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | dumai
# Processing Record 21 of Set 4 | leshukonskoye
# Processing Record 22 of Set 4 | bouza
# Processing Record 23 of Set 4 | qasigiannguit
# Processing Record 24 of Set 4 | ayios matthaios
# City not found. Skipping...
# Processing Record 25 of Set 4 | kirakira
# Processing Record 26 of Set 4 | mizque
# Processing Record 27 of Set 4 | oriximina
# Processing Record 28 of Set 4 | boende
# Processing Record 29 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 4 | umm kaddadah
# Processing Record 31 of Set 4 | alihe
# Processing Record 32 of Set 4 | kangaatsiaq
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | boa vista
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | baykit
# Processing Record 40 of Set 4 | toowoomba
# Processing Record 41 of Set 4 | onokhoy
# Processing Record 42 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 43 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | ust-koksa
# Processing Record 46 of Set 4 | contramaestre
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 50 of Set 4 | yerofey pavlovich
# Processing Record 1 of Set 5 | nome
# Processing Record 2 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 5 | nongan
# Processing Record 4 of Set 5 | marondera
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | kenai
# Processing Record 8 of Set 5 | kang
# Processing Record 9 of Set 5 | nogales
# Processing Record 10 of Set 5 | henties bay
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | severnoye
# Processing Record 13 of Set 5 | yakshur-bodya
# City not found. Skipping...
# Processing Record 14 of Set 5 | sao benedito do rio preto
# Processing Record 15 of Set 5 | guerrero negro
# Processing Record 16 of Set 5 | baiyin
# Processing Record 17 of Set 5 | williams lake
# Processing Record 18 of Set 5 | los llanos de aridane
# Processing Record 19 of Set 5 | kaura namoda
# Processing Record 20 of Set 5 | smolenskoye
# Processing Record 21 of Set 5 | tucurui
# Processing Record 22 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 5 | palu
# Processing Record 24 of Set 5 | deville-les-rouen
# Processing Record 25 of Set 5 | arraial do cabo
# Processing Record 26 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 27 of Set 5 | tevaitoa
# Processing Record 28 of Set 5 | ivankiv
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | waddan
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | mont-de-marsan
# Processing Record 33 of Set 5 | gat
# Processing Record 34 of Set 5 | hamilton
# Processing Record 35 of Set 5 | east hemet
# Processing Record 36 of Set 5 | shingu
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | moree
# Processing Record 39 of Set 5 | mapiri
# Processing Record 40 of Set 5 | paita
# Processing Record 41 of Set 5 | bayevo
# Processing Record 42 of Set 5 | yashan
# Processing Record 43 of Set 5 | nganjuk
# Processing Record 44 of Set 5 | castro
# Processing Record 45 of Set 5 | svetlogorsk
# Processing Record 46 of Set 5 | teguldet
# Processing Record 47 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | san patricio
# Processing Record 50 of Set 5 | nurota
# Processing Record 1 of Set 6 | tupik
# Processing Record 2 of Set 6 | la seyne-sur-mer
# Processing Record 3 of Set 6 | boblingen
# Processing Record 4 of Set 6 | villarrica
# Processing Record 5 of Set 6 | camacha
# Processing Record 6 of Set 6 | portland
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | gerash
# Processing Record 9 of Set 6 | buchanan
# Processing Record 10 of Set 6 | yellowknife
# Processing Record 11 of Set 6 | banjar
# Processing Record 12 of Set 6 | iranshahr
# Processing Record 13 of Set 6 | red bluff
# Processing Record 14 of Set 6 | cabedelo
# Processing Record 15 of Set 6 | el escorial
# Processing Record 16 of Set 6 | tres passos
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | yarada
# Processing Record 21 of Set 6 | bima
# Processing Record 22 of Set 6 | male
# Processing Record 23 of Set 6 | cherskiy
# Processing Record 24 of Set 6 | kavaratti
# Processing Record 25 of Set 6 | yar-sale
# Processing Record 26 of Set 6 | bandiagara
# Processing Record 27 of Set 6 | ulaangom
# Processing Record 28 of Set 6 | nelson
# Processing Record 29 of Set 6 | hovd
# Processing Record 30 of Set 6 | nalut
# Processing Record 31 of Set 6 | san blas
# Processing Record 32 of Set 6 | pachino
# Processing Record 33 of Set 6 | bandarbeyla
# Processing Record 34 of Set 6 | qaqortoq
# Processing Record 35 of Set 6 | kontagora
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | ahipara
# Processing Record 38 of Set 6 | georgetown
# Processing Record 39 of Set 6 | saint-jovite
# Processing Record 40 of Set 6 | sola
# Processing Record 41 of Set 6 | arandis
# Processing Record 42 of Set 6 | berbera
# Processing Record 43 of Set 6 | anloga
# Processing Record 44 of Set 6 | pangnirtung
# Processing Record 45 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 6 | vanimo
# Processing Record 47 of Set 6 | arcachon
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | fortuna
# Processing Record 50 of Set 6 | seymchan
# Processing Record 1 of Set 7 | quatre cocos
# Processing Record 2 of Set 7 | victoria
# Processing Record 3 of Set 7 | birjand
# Processing Record 4 of Set 7 | kitgum
# Processing Record 5 of Set 7 | santa engracia
# Processing Record 6 of Set 7 | qax
# Processing Record 7 of Set 7 | sao sebastiao
# Processing Record 8 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 7 | caluquembe
# Processing Record 10 of Set 7 | muroto
# Processing Record 11 of Set 7 | natal
# Processing Record 12 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 7 | coihaique
# Processing Record 14 of Set 7 | north bend
# Processing Record 15 of Set 7 | tarauaca
# Processing Record 16 of Set 7 | abu zabad
# Processing Record 17 of Set 7 | pemangkat
# Processing Record 18 of Set 7 | ulyanovo
# City not found. Skipping...
# Processing Record 19 of Set 7 | coahuayana
# Processing Record 20 of Set 7 | ust-tsilma
# Processing Record 21 of Set 7 | lagoa
# Processing Record 22 of Set 7 | mayo
# Processing Record 23 of Set 7 | feldkirchen an der donau
# Processing Record 24 of Set 7 | dunedin
# Processing Record 25 of Set 7 | pingliang
# Processing Record 26 of Set 7 | baillif
# Processing Record 27 of Set 7 | coffs harbour
# Processing Record 28 of Set 7 | breytovo
# Processing Record 29 of Set 7 | maarianhamina
# Processing Record 30 of Set 7 | melo
# Processing Record 31 of Set 7 | ouallam
# Processing Record 32 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 7 | panaba
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | fecamp
# Processing Record 37 of Set 7 | paamiut
# Processing Record 38 of Set 7 | tambun
# Processing Record 39 of Set 7 | sao gabriel da cachoeira
# Processing Record 40 of Set 7 | lavrentiya
# Processing Record 41 of Set 7 | zwijndrecht
# Processing Record 42 of Set 7 | bengkulu
# Processing Record 43 of Set 7 | gadung
# Processing Record 44 of Set 7 | dalianwan
# Processing Record 45 of Set 7 | uwajima
# Processing Record 46 of Set 7 | xiongzhou
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | kamaishi
# Processing Record 49 of Set 7 | mantua
# Processing Record 50 of Set 7 | halkirk
# Processing Record 1 of Set 8 | bamiantong
# Processing Record 2 of Set 8 | sadat
# Processing Record 3 of Set 8 | karasjok
# Processing Record 4 of Set 8 | kurilsk
# Processing Record 5 of Set 8 | sembakung
# Processing Record 6 of Set 8 | nobres
# Processing Record 7 of Set 8 | jawhar
# Processing Record 8 of Set 8 | anderson
# Processing Record 9 of Set 8 | buxton
# Processing Record 10 of Set 8 | inhambane
# Processing Record 11 of Set 8 | ewa beach
# Processing Record 12 of Set 8 | kyabe
# Processing Record 13 of Set 8 | naujoji akmene
# Processing Record 14 of Set 8 | joao pinheiro
# Processing Record 15 of Set 8 | baft
# Processing Record 16 of Set 8 | sakakah
# Processing Record 17 of Set 8 | tigre
# Processing Record 18 of Set 8 | puri
# Processing Record 19 of Set 8 | guadalajara
# Processing Record 20 of Set 8 | usvyaty
# Processing Record 21 of Set 8 | tshikapa
# Processing Record 22 of Set 8 | oranjestad
# Processing Record 23 of Set 8 | tete
# Processing Record 24 of Set 8 | orumiyeh
# Processing Record 25 of Set 8 | saint-georges
# Processing Record 26 of Set 8 | spirit river
# Processing Record 27 of Set 8 | kazachinskoye
# Processing Record 28 of Set 8 | ayan
# Processing Record 29 of Set 8 | rocha
# Processing Record 30 of Set 8 | saint anthony
# Processing Record 31 of Set 8 | gilbues
# Processing Record 32 of Set 8 | itaparica
# Processing Record 33 of Set 8 | tahta
# Processing Record 34 of Set 8 | la plata
# Processing Record 35 of Set 8 | sisimiut
# Processing Record 36 of Set 8 | half moon bay
# Processing Record 37 of Set 8 | aklavik
# Processing Record 38 of Set 8 | bayji
# Processing Record 39 of Set 8 | wahiawa
# Processing Record 40 of Set 8 | kenitra
# Processing Record 41 of Set 8 | port-gentil
# Processing Record 42 of Set 8 | uyuni
# Processing Record 43 of Set 8 | waipawa
# Processing Record 44 of Set 8 | longyearbyen
# Processing Record 45 of Set 8 | jensen beach
# Processing Record 46 of Set 8 | san quintin
# Processing Record 47 of Set 8 | yulara
# Processing Record 48 of Set 8 | nizhniy tsasuchey
# Processing Record 49 of Set 8 | caravelas
# Processing Record 50 of Set 8 | batemans bay
# Processing Record 1 of Set 9 | xingyi
# Processing Record 2 of Set 9 | jiazi
# Processing Record 3 of Set 9 | la trinidad
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | saint-leu
# Processing Record 7 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 9 | mitsamiouli
# Processing Record 9 of Set 9 | kamakwie
# Processing Record 10 of Set 9 | talara
# Processing Record 11 of Set 9 | saint-pierre
# Processing Record 12 of Set 9 | borama
# City not found. Skipping...
# Processing Record 13 of Set 9 | kruisfontein
# Processing Record 14 of Set 9 | saldanha
# Processing Record 15 of Set 9 | nova granada
# Processing Record 16 of Set 9 | yantal
# Processing Record 17 of Set 9 | wenling
# Processing Record 18 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 9 | san fernando
# Processing Record 20 of Set 9 | teya
# Processing Record 21 of Set 9 | constitucion
# Processing Record 22 of Set 9 | mishkino
# Processing Record 23 of Set 9 | payo
# Processing Record 24 of Set 9 | skibbereen
# Processing Record 25 of Set 9 | proletariy
# Processing Record 26 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 9 | flinders
# Processing Record 28 of Set 9 | groa
# Processing Record 29 of Set 9 | oga
# Processing Record 30 of Set 9 | lasa
# Processing Record 31 of Set 9 | praia
# Processing Record 32 of Set 9 | kaeo
# Processing Record 33 of Set 9 | ahuimanu
# Processing Record 34 of Set 9 | kalemie
# Processing Record 35 of Set 9 | praia da vitoria
# Processing Record 36 of Set 9 | yurgamysh
# Processing Record 37 of Set 9 | anadyr
# Processing Record 38 of Set 9 | naze
# Processing Record 39 of Set 9 | marawi
# Processing Record 40 of Set 9 | abha
# Processing Record 41 of Set 9 | itaituba
# Processing Record 42 of Set 9 | la libertad
# Processing Record 43 of Set 9 | cap malheureux
# Processing Record 44 of Set 9 | roald
# Processing Record 45 of Set 9 | olden
# Processing Record 46 of Set 9 | verkhniy avzyan
# Processing Record 47 of Set 9 | jacareacanga
# Processing Record 48 of Set 9 | zhezkazgan
# Processing Record 49 of Set 9 | ampanihy
# Processing Record 50 of Set 9 | omegna
# Processing Record 1 of Set 10 | kalabo
# Processing Record 2 of Set 10 | santa rosalia
# Processing Record 3 of Set 10 | majene
# Processing Record 4 of Set 10 | buala
# Processing Record 5 of Set 10 | yerbogachen
# Processing Record 6 of Set 10 | alofi
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | gloversville
# Processing Record 9 of Set 10 | fort saint james
# Processing Record 10 of Set 10 | maradi
# Processing Record 11 of Set 10 | belmonte
# Processing Record 12 of Set 10 | kahului
# Processing Record 13 of Set 10 | callaway
# Processing Record 14 of Set 10 | areosa
# Processing Record 15 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 10 | faya
# Processing Record 17 of Set 10 | komsomolskiy
# Processing Record 18 of Set 10 | kimbe
# Processing Record 19 of Set 10 | yinchuan
# Processing Record 20 of Set 10 | changji
# Processing Record 21 of Set 10 | fray bentos
# Processing Record 22 of Set 10 | mandiana
# Processing Record 23 of Set 10 | angra
# City not found. Skipping...
# Processing Record 24 of Set 10 | atherton
# Processing Record 25 of Set 10 | jiwani
# Processing Record 26 of Set 10 | grand gaube
# Processing Record 27 of Set 10 | taywarah
# Processing Record 28 of Set 10 | tessalit
# Processing Record 29 of Set 10 | idrinskoye
# Processing Record 30 of Set 10 | laguna
# Processing Record 31 of Set 10 | qena
# Processing Record 32 of Set 10 | jurm
# Processing Record 33 of Set 10 | haines junction
# Processing Record 34 of Set 10 | hamadan
# Processing Record 35 of Set 10 | vaitape
# Processing Record 36 of Set 10 | dukat
# Processing Record 37 of Set 10 | fukue
# Processing Record 38 of Set 10 | ishigaki
# Processing Record 39 of Set 10 | vestmanna
# Processing Record 40 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | rapid valley
# Processing Record 42 of Set 10 | itororo
# Processing Record 43 of Set 10 | sept-iles
# Processing Record 44 of Set 10 | manta
# Processing Record 45 of Set 10 | lindi
# Processing Record 46 of Set 10 | brahmapuri
# City not found. Skipping...
# Processing Record 47 of Set 10 | san cristobal
# Processing Record 48 of Set 10 | manono
# Processing Record 49 of Set 10 | rubtsovsk
# Processing Record 50 of Set 10 | kamenka
# Processing Record 1 of Set 11 | misratah
# Processing Record 2 of Set 11 | chicama
# Processing Record 3 of Set 11 | vanderhoof
# Processing Record 4 of Set 11 | la asuncion
# Processing Record 5 of Set 11 | okhotsk
# Processing Record 6 of Set 11 | isangel
# Processing Record 7 of Set 11 | ulundi
# Processing Record 8 of Set 11 | yaritagua
# Processing Record 9 of Set 11 | sao pedro
# Processing Record 10 of Set 11 | mezen
# Processing Record 11 of Set 11 | samarai
# Processing Record 12 of Set 11 | vao
# Processing Record 13 of Set 11 | dunmore east
# Processing Record 14 of Set 11 | arona
# Processing Record 15 of Set 11 | ukiah
# Processing Record 16 of Set 11 | baturaja
# Processing Record 17 of Set 11 | north platte
# Processing Record 18 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 19 of Set 11 | thunder bay
# Processing Record 20 of Set 11 | alta floresta
# Processing Record 21 of Set 11 | korla
# Processing Record 22 of Set 11 | harper
# Processing Record 23 of Set 11 | zurrieq
# Processing Record 24 of Set 11 | navolato
# Processing Record 25 of Set 11 | bermejo
# Processing Record 26 of Set 11 | urdoma
# Processing Record 27 of Set 11 | jiayuguan
# Processing Record 28 of Set 11 | jhalawar
# Processing Record 29 of Set 11 | tutoia
# Processing Record 30 of Set 11 | burica
# City not found. Skipping...
# Processing Record 31 of Set 11 | bharatpur
# Processing Record 32 of Set 11 | uruacu
# Processing Record 33 of Set 11 | ajaccio
# Processing Record 34 of Set 11 | guerande
# Processing Record 35 of Set 11 | portel
# Processing Record 36 of Set 11 | cidreira
# Processing Record 37 of Set 11 | tamuin
# Processing Record 38 of Set 11 | karratha
# Processing Record 39 of Set 11 | kharovsk
# Processing Record 40 of Set 11 | grants
# Processing Record 41 of Set 11 | iralaya
# Processing Record 42 of Set 11 | dharangaon
# Processing Record 43 of Set 11 | touros
# Processing Record 44 of Set 11 | douentza
# Processing Record 45 of Set 11 | bara
# Processing Record 46 of Set 11 | mehamn
# Processing Record 47 of Set 11 | conceicao do mato dentro
# Processing Record 48 of Set 11 | xining
# Processing Record 49 of Set 11 | ust-maya
# Processing Record 50 of Set 11 | xuanhua
# Processing Record 1 of Set 12 | saint-francois
# Processing Record 2 of Set 12 | lata
# Processing Record 3 of Set 12 | hailey
# Processing Record 4 of Set 12 | gazanjyk
# Processing Record 5 of Set 12 | kralendijk
# Processing Record 6 of Set 12 | fez
# Processing Record 7 of Set 12 | ketchikan
# Processing Record 8 of Set 12 | talas
# Processing Record 9 of Set 12 | trapani
# Processing Record 10 of Set 12 | severomorsk
# Processing Record 11 of Set 12 | ossora
# Processing Record 12 of Set 12 | bambous virieux
# Processing Record 13 of Set 12 | fare
# Processing Record 14 of Set 12 | basoko
# Processing Record 15 of Set 12 | colquechaca
# Processing Record 16 of Set 12 | sharjah
# Processing Record 17 of Set 12 | cuiluan
# Processing Record 18 of Set 12 | manaus
# Processing Record 19 of Set 12 | wanaka
# Processing Record 20 of Set 12 | vestmannaeyjar
# Processing Record 21 of Set 12 | vung tau
# Processing Record 22 of Set 12 | pore
# Processing Record 23 of Set 12 | berlevag
# Processing Record 24 of Set 12 | viedma
# Processing Record 25 of Set 12 | manadhoo
# Processing Record 26 of Set 12 | rock sound
# Processing Record 27 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 12 | brigantine
# Processing Record 30 of Set 12 | ucluelet
# Processing Record 31 of Set 12 | qingdao
# Processing Record 32 of Set 12 | winneba
# Processing Record 33 of Set 12 | manggar
# Processing Record 34 of Set 12 | vzmorye
# Processing Record 35 of Set 12 | mariental
# Processing Record 36 of Set 12 | jumla
# Processing Record 37 of Set 12 | alto araguaia
# Processing Record 38 of Set 12 | beypur
# City not found. Skipping...
# Processing Record 39 of Set 12 | saryg-sep
# Processing Record 40 of Set 12 | leeton
# Processing Record 41 of Set 12 | vila
# Processing Record 42 of Set 12 | kitimat
# Processing Record 43 of Set 12 | biak
# Processing Record 44 of Set 12 | chaa-khol
# City not found. Skipping...
# Processing Record 45 of Set 12 | carangola
# Processing Record 46 of Set 12 | byron bay
# Processing Record 47 of Set 12 | fort dodge
# Processing Record 48 of Set 12 | ende
# Processing Record 49 of Set 12 | yangjiang
# Processing Record 50 of Set 12 | roma
# Processing Record 1 of Set 13 | broken hill
# Processing Record 2 of Set 13 | merauke
# Processing Record 3 of Set 13 | atkarsk
# Processing Record 4 of Set 13 | witrivier
# City not found. Skipping...
# Processing Record 5 of Set 13 | baruun-urt
# Processing Record 6 of Set 13 | owando
# Processing Record 7 of Set 13 | la tuque
# Processing Record 8 of Set 13 | andra
# Processing Record 9 of Set 13 | soyo
# Processing Record 10 of Set 13 | najran
# Processing Record 11 of Set 13 | avera
# Processing Record 12 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 13 | fengrun
# Processing Record 14 of Set 13 | chabahar
# Processing Record 15 of Set 13 | xuddur
# Processing Record 16 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 13 | kloulklubed
# Processing Record 18 of Set 13 | port macquarie
# Processing Record 19 of Set 13 | axixa do tocantins
# City not found. Skipping...
# Processing Record 20 of Set 13 | kapuskasing
# Processing Record 21 of Set 13 | sinnamary
# Processing Record 22 of Set 13 | zhigansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data2_df= pd.DataFrame(city_data)
city_data2_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Rikitea -23.12 -134.97     72.48        78          47
# 1             Yumen  40.28   97.20     86.54        12          98
# 2        Winnemucca  40.97 -117.74     53.60        18           1
# 3           Qaanaaq  77.48  -69.36     37.31        87         100
# 4          Tasiilaq  65.61  -37.64     48.20        60          69
# ..              ...    ...     ...       ...       ...         ...
# 565     Kloulklubed   7.04  134.26     82.40        83          75
# 566  Port Macquarie -31.43  152.92     51.01        95          13
# 567     Kapuskasing  49.42  -82.43     50.00        93          90
# 568       Sinnamary   5.38  -52.95     77.67        85          87
# 569        Zhigansk  66.77  123.37     65.64        45          24
#
#      Wind Speed Country Current Description
# 0         11.12      PF    scattered clouds
# 1         23.71      CN     overcast clouds
# 2          6.93      US           clear sky
# 3         16.96      GL          light rain
# 4          5.82      GL       broken clouds
# ..          ...     ...                 ...
# 565        3.36      PW       broken clouds
# 566        4.18      AU          few clouds
# 567       12.75      CA                mist
# 568        7.09      GF          light rain
# 569       12.48      RU          few clouds
#
# [570 rows x 9 columns]

# %%
city_data_df = city_data2_df[ ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"] ]
city_data_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Rikitea      PF -23.12 -134.97     72.48        78          47
# 1       Yumen      CN  40.28   97.20     86.54        12          98
# 2  Winnemucca      US  40.97 -117.74     53.60        18           1
# 3     Qaanaaq      GL  77.48  -69.36     37.31        87         100
# 4    Tasiilaq      GL  65.61  -37.64     48.20        60          69
#
#    Wind Speed Current Description
# 0       11.12    scattered clouds
# 1       23.71     overcast clouds
# 2        6.93           clear sky
# 3       16.96          light rain
# 4        5.82       broken clouds

# %%
# Create the output file (CSV).
output_data_file = 'Weather_Database/WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='WeatherPy_Database')
